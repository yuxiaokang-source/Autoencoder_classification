# %% [markdown]
# # 数据预处理

# %%
#导入torch部分
import torch
import torch
torch.manual_seed(1)
from torch.nn import Linear
from torch.autograd import Variable
import torch.nn as nn

import os
os.chdir("/home/zhangjingxiao/yxk/autoencoder/Retina")
import sklearn
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
from numpy import linalg
from numpy.linalg import norm
from scipy.spatial.distance import squareform, pdist
#from keras import regularizers
from sklearn.preprocessing import scale
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.manifold.t_sne import (_joint_probabilities,_kl_divergence)
from time import time
import numpy as np
from sklearn.cluster import KMeans
from IPython.display import Image
from sklearn.metrics import accuracy_score
import sklearn.metrics
import matplotlib.pyplot as plt
import os
os.environ['PYTHONHASHSEED'] = '0'
import pandas as pd
import numpy as np
import scanpy.api as sc
from scipy.sparse import issparse
from time import time
import scipy.io
import pickle

from sklearn.utils import shuffle
import pandas as pd
import numpy as np
import umap
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/zhangjingxiao/.conda/envs/py36/lib/python3.6/site-packages/scanpy/api/__init__.py:6: FutureWarning:
#
# In a future version of Scanpy, `scanpy.api` will be removed.
# Simply use `import scanpy as sc` and `import scanpy.external as sce` instead.
#
#   FutureWarning,

# %% [markdown]
# # MMDloss

# %%
import torch

min_var_est = 1e-8


# Consider linear time MMD with a linear kernel:
# K(f(x), f(y)) = f(x)^Tf(y)
# h(z_i, z_j) = k(x_i, x_j) + k(y_i, y_j) - k(x_i, y_j) - k(x_j, y_i)
#             = [f(x_i) - f(y_i)]^T[f(x_j) - f(y_j)]
#
# f_of_X: batch_size * k
# f_of_Y: batch_size * k
def linear_mmd2(f_of_X, f_of_Y):
    loss = 0.0
    delta = f_of_X - f_of_Y
    loss = torch.mean((delta[:-1] * delta[1:]).sum(1))
    return loss


# Consider linear time MMD with a polynomial kernel:
# K(f(x), f(y)) = (alpha*f(x)^Tf(y) + c)^d
# f_of_X: batch_size * k
# f_of_Y: batch_size * k
def poly_mmd2(f_of_X, f_of_Y, d=2, alpha=1.0, c=2.0):
    K_XX = (alpha * (f_of_X[:-1] * f_of_X[1:]).sum(1) + c)
    K_XX_mean = torch.mean(K_XX.pow(d))

    K_YY = (alpha * (f_of_Y[:-1] * f_of_Y[1:]).sum(1) + c)
    K_YY_mean = torch.mean(K_YY.pow(d))

    K_XY = (alpha * (f_of_X[:-1] * f_of_Y[1:]).sum(1) + c)
    K_XY_mean = torch.mean(K_XY.pow(d))

    K_YX = (alpha * (f_of_Y[:-1] * f_of_X[1:]).sum(1) + c)
    K_YX_mean = torch.mean(K_YX.pow(d))

    return K_XX_mean + K_YY_mean - K_XY_mean - K_YX_mean


def _mix_rbf_kernel(X, Y, sigma_list):
    assert(X.size(0) == Y.size(0))
    m = X.size(0)

    Z = torch.cat((X, Y), 0)
    ZZT = torch.mm(Z, Z.t())
    diag_ZZT = torch.diag(ZZT).unsqueeze(1)
    Z_norm_sqr = diag_ZZT.expand_as(ZZT)
    exponent = Z_norm_sqr - 2 * ZZT + Z_norm_sqr.t()

    K = 0.0
    for sigma in sigma_list:
        gamma = 1.0 / (2 * sigma**2)
        K += torch.exp(-gamma * exponent)

    return K[:m, :m], K[:m, m:], K[m:, m:], len(sigma_list)


def mix_rbf_mmd2(X, Y, sigma_list, biased=True):
    K_XX, K_XY, K_YY, d = _mix_rbf_kernel(X, Y, sigma_list)
    # return _mmd2(K_XX, K_XY, K_YY, const_diagonal=d, biased=biased)
    return _mmd2(K_XX, K_XY, K_YY, const_diagonal=False, biased=biased)


def mix_rbf_mmd2_and_ratio(X, Y, sigma_list, biased=True):
    K_XX, K_XY, K_YY, d = _mix_rbf_kernel(X, Y, sigma_list)
    # return _mmd2_and_ratio(K_XX, K_XY, K_YY, const_diagonal=d, biased=biased)
    return _mmd2_and_ratio(K_XX, K_XY, K_YY, const_diagonal=False, biased=biased)


################################################################################
# Helper functions to compute variances based on kernel matrices
################################################################################


def _mmd2(K_XX, K_XY, K_YY, const_diagonal=False, biased=False):
    m = K_XX.size(0)    # assume X, Y are same shape

    # Get the various sums of kernels that we'll use
    # Kts drop the diagonal, but we don't need to compute them explicitly
    if const_diagonal is not False:
        diag_X = diag_Y = const_diagonal
        sum_diag_X = sum_diag_Y = m * const_diagonal
    else:
        diag_X = torch.diag(K_XX)                       # (m,)
        diag_Y = torch.diag(K_YY)                       # (m,)
        sum_diag_X = torch.sum(diag_X)
        sum_diag_Y = torch.sum(diag_Y)

    Kt_XX_sums = K_XX.sum(dim=1) - diag_X             # \tilde{K}_XX * e = K_XX * e - diag_X
    Kt_YY_sums = K_YY.sum(dim=1) - diag_Y             # \tilde{K}_YY * e = K_YY * e - diag_Y
    K_XY_sums_0 = K_XY.sum(dim=0)                     # K_{XY}^T * e

    Kt_XX_sum = Kt_XX_sums.sum()                       # e^T * \tilde{K}_XX * e
    Kt_YY_sum = Kt_YY_sums.sum()                       # e^T * \tilde{K}_YY * e
    K_XY_sum = K_XY_sums_0.sum()                       # e^T * K_{XY} * e

    if biased:
        mmd2 = ((Kt_XX_sum + sum_diag_X) / (m * m)
            + (Kt_YY_sum + sum_diag_Y) / (m * m)
            - 2.0 * K_XY_sum / (m * m))
    else:
        mmd2 = (Kt_XX_sum / (m * (m - 1))
            + Kt_YY_sum / (m * (m - 1))
            - 2.0 * K_XY_sum / (m * m))

    return mmd2


def _mmd2_and_ratio(K_XX, K_XY, K_YY, const_diagonal=False, biased=False):
    mmd2, var_est = _mmd2_and_variance(K_XX, K_XY, K_YY, const_diagonal=const_diagonal, biased=biased)
    loss = mmd2 / torch.sqrt(torch.clamp(var_est, min=min_var_est))
    return loss, mmd2, var_est


def _mmd2_and_variance(K_XX, K_XY, K_YY, const_diagonal=False, biased=False):
    m = K_XX.size(0)    # assume X, Y are same shape

    # Get the various sums of kernels that we'll use
    # Kts drop the diagonal, but we don't need to compute them explicitly
    if const_diagonal is not False:
        diag_X = diag_Y = const_diagonal
        sum_diag_X = sum_diag_Y = m * const_diagonal
        sum_diag2_X = sum_diag2_Y = m * const_diagonal**2
    else:
        diag_X = torch.diag(K_XX)                       # (m,)
        diag_Y = torch.diag(K_YY)                       # (m,)
        sum_diag_X = torch.sum(diag_X)
        sum_diag_Y = torch.sum(diag_Y)
        sum_diag2_X = diag_X.dot(diag_X)
        sum_diag2_Y = diag_Y.dot(diag_Y)

    Kt_XX_sums = K_XX.sum(dim=1) - diag_X             # \tilde{K}_XX * e = K_XX * e - diag_X
    Kt_YY_sums = K_YY.sum(dim=1) - diag_Y             # \tilde{K}_YY * e = K_YY * e - diag_Y
    K_XY_sums_0 = K_XY.sum(dim=0)                     # K_{XY}^T * e
    K_XY_sums_1 = K_XY.sum(dim=1)                     # K_{XY} * e

    Kt_XX_sum = Kt_XX_sums.sum()                       # e^T * \tilde{K}_XX * e
    Kt_YY_sum = Kt_YY_sums.sum()                       # e^T * \tilde{K}_YY * e
    K_XY_sum = K_XY_sums_0.sum()                       # e^T * K_{XY} * e

    Kt_XX_2_sum = (K_XX ** 2).sum() - sum_diag2_X      # \| \tilde{K}_XX \|_F^2
    Kt_YY_2_sum = (K_YY ** 2).sum() - sum_diag2_Y      # \| \tilde{K}_YY \|_F^2
    K_XY_2_sum  = (K_XY ** 2).sum()                    # \| K_{XY} \|_F^2

    if biased:
        mmd2 = ((Kt_XX_sum + sum_diag_X) / (m * m)
            + (Kt_YY_sum + sum_diag_Y) / (m * m)
            - 2.0 * K_XY_sum / (m * m))
    else:
        mmd2 = (Kt_XX_sum / (m * (m - 1))
            + Kt_YY_sum / (m * (m - 1))
            - 2.0 * K_XY_sum / (m * m))

    var_est = (
        2.0 / (m**2 * (m - 1.0)**2) * (2 * Kt_XX_sums.dot(Kt_XX_sums) - Kt_XX_2_sum + 2 * Kt_YY_sums.dot(Kt_YY_sums) - Kt_YY_2_sum)
        - (4.0*m - 6.0) / (m**3 * (m - 1.0)**3) * (Kt_XX_sum**2 + Kt_YY_sum**2)
        + 4.0*(m - 2.0) / (m**3 * (m - 1.0)**2) * (K_XY_sums_1.dot(K_XY_sums_1) + K_XY_sums_0.dot(K_XY_sums_0))
        - 4.0*(m - 3.0) / (m**3 * (m - 1.0)**2) * (K_XY_2_sum) - (8 * m - 12) / (m**5 * (m - 1)) * K_XY_sum**2
        + 8.0 / (m**3 * (m - 1.0)) * (
            1.0 / m * (Kt_XX_sum + Kt_YY_sum) * K_XY_sum
            - Kt_XX_sums.dot(K_XY_sums_1)
            - Kt_YY_sums.dot(K_XY_sums_0))
        )
    return mmd2, var_est

# %%
def creatadata(datadir):
    print("Start reading expression data (matrix.mtx)")
    #setp1-1 read matrix
    mtx=sc.read_mtx(os.path.join(datadir,"matrix.mtx"))
    print("Start reading cell information (barcodes.tsv), may including cellname, celltype....")
    #step1-2 cell information
    cell_info=pd.read_csv(os.path.join(datadir,"barcodes.tsv"),sep="\t",header=0,na_filter=False)    #or header=None
    #step1-3 gene information
    print("Start reading gene information (genes.tsv), including genename,geneid,....")
    gene_info=pd.read_csv(os.path.join(datadir,"genes.tsv"),sep="\t",header=0,na_filter=False)
    #step 1-4 create anndata
    adata=sc.AnnData(mtx.X.transpose(),obs=cell_info,var=gene_info)
    del mtx
    adata.obs_names=adata.obs['cellname'].values
    adata.var_names=adata.var['genename'].values
    adata.obs_names_make_unique(join="-") #Makes the elements of a character vector unique by appending "-" to duplicates.
    adata.obs_names_make_unique(join="-") #Makes the elements of a character vector unique by appending "-" to duplicates.
    adata.var_names_make_unique(join="-") #Makes the elements of a character vector unique by appending "-" to duplicates.
    adata.var_names_make_unique(join="-") #Makes the elements of a character vector unique by appending "-" to duplicates.
    #adata.obs['dataset_label']=dataset
    return adata,adata.obs,adata.var

#read data
x=time()
adata,_,_=creatadata(datadir="/home/zhangjingxiao/yxk/autoencoder/Retina")
print("time of reading data is ",time()-x)

# preprocess
#normalize data
sc.pp.normalize_per_cell(adata,counts_per_cell_after=1e4)
sc.pp.filter_genes(adata,min_cells=1)
sc.pp.filter_genes_dispersion(adata,n_top_genes =1000) #top 1000 gene
#log1p data
sc.pp.log1p(adata)
#sc.pp.scale(adata)

#直接按两个batch做
maprule = {'Bipolar1':'bt1','Bipolar2':'bt1','Bipolar3':'bt1','Bipolar4':'bt1',
'Bipolar5':'bt2','Bipolar6':'bt2'}
adata.obs['BatchIDnew'] = adata.obs.BatchID.map(maprule)

#batch1,adata1 n_obs*n_vars=12364*1000
adata1=adata[adata.obs['BatchID'].isin(['Bipolar1','Bipolar2','Bipolar3','Bipolar4'])].copy()
sc.pp.scale(adata1)#
#batch2,adata2,n_obs*n_vars=11130*1000
adata2=adata[adata.obs['BatchID'].isin(['Bipolar5','Bipolar6'])].copy()
sc.pp.scale(adata2)

adata_con=sc.AnnData.concatenate(adata1,adata2)
sc.pp.scale(adata)
# Out:
# Start reading expression data (matrix.mtx)
# Transforming to str index.
# Transforming to str index.
# Start reading cell information (barcodes.tsv), may including cellname, celltype....
# Start reading gene information (genes.tsv), including genename,geneid,....
# time of reading data is  43.60984754562378

# %%
#全部数据进行统一scale，可视化
sc.pp.neighbors(adata,n_neighbors=15,random_state=0)
sc.tl.umap(adata)
sc.pl.umap(adata,color=['BatchIDnew','BatchID','celltype'],title=["all data scale(BatchIDnew)","all data scale(BatchID)","all data scale(celltype)"])

#分别的batch进行scale，再合并，进行可视化
sc.pp.neighbors(adata_con,n_neighbors=15,random_state=0)
sc.tl.umap(adata_con)
sc.pl.umap(adata_con,color=['BatchIDnew','BatchID','celltype'],title="separate data scale")
# Out:
# WARNING: You’re trying to run this on 1000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# ... storing 'celltype' as categorical
# ... storing 'celltype_com' as categorical
# ... storing 'BatchID' as categorical
# ... storing 'BatchIDnew' as categorical
# WARNING: You’re trying to run this on 1000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# ... storing 'BatchID' as categorical
# ... storing 'BatchIDnew' as categorical
# ... storing 'celltype' as categorical
# ... storing 'celltype_com' as categorical
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.

# %% [markdown]
# # DataLoader

# %%
import ipdb
#首先将数据集进行切分
from sklearn.model_selection import train_test_split #每个batch各0.8
adata1_train,adata1_test=train_test_split(adata1,test_size=0.2,random_state=0)
adata2_train,adata2_test=train_test_split(adata2,test_size=0.2,random_state=0)

adata_train_con=sc.AnnData.concatenate(adata1_train,adata2_train)
adata_test_con=sc.AnnData.concatenate(adata1_test,adata2_test)

# train_bat_id1=adata1_train.obs["BatchIDnew"]
# train_bat_id2=adata2_train.obs["BatchIDnew"]

# test_bat_id1=adata1_test.obs["BatchIDnew"]
# test_bat_id2=adata2_test.obs["BatchIDnew"]

adata_train={"bt1":adata1_train.X,'bt2':adata2_train.X}

adata_test={"bt1":adata1_test.X,'bt2':adata2_test.X}


#传进来的时候
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
#定义Mydataset继承自Dataset,并重写__getitem__和__len__,Dataset是基类
class Mydataset(Dataset):#穿一个Data一个字典的形式进来
    def __init__(self, num_batch,batch_size,data):
        super(Mydataset, self).__init__()
        self.num_batch=num_batch#
        self.data=data
        self.batch_size=batch_size
    # indexing
    def __getitem__(self, index):
        #ipdb.set_trace()
        temp=np.array([]).reshape(-1,1000)
        for ind in self.data:
            dat=self.data[ind];
            row = np.random.randint(0,dat.shape[0],size=self.batch_size)
            temp=np.concatenate((temp,dat[row,:]))
            #这个地方确实很奇怪哈，DataLoader里面的batch_size设置为多大，返回的数据第一维就是多大
            #我之前batch_size=100,最终一个batch的数据式（100，200，1000）
        return temp
    #返回数据集大小，应该是（x_transpose,y_transpose）大小即num*2，这里我直接返回了num
    def __len__(self):
        #ipdb.set_trace()
        min_len=np.inf;
        for index in self.data:
            dat=self.data[index]
            min_len=min(min_len,torch.tensor(dat).size(0))
        return min_len//(self.batch_size)
    
trainLoder=Mydataset(2,100,adata_train)
trainData=DataLoader(trainLoder,batch_size=1)#len(trainData)=90
testLoder=Mydataset(2,100,adata_test)
testData=DataLoader(testLoder,batch_size=1)#len(trainData)=90
# for dat in trainData:
#     print(dat)
#     print(dat.shape)
#     break
# print(len(trainData))
# print(len(testData))

# %% [markdown]
# # 参数设置

# %%
num_batch=2
labda=9
num_iter=100
base = 1.0
sigma_list = [1, 2, 4]
sigma_list = [sigma / base for sigma in sigma_list]

# %% [markdown]
# # 网络结构
# $lambda=9$
#
# $loss=lambda*resconstructionLoss+mmdLoss()$

# %%
#!/usr/bin/env python
import torch.nn as nn
import torch
import torch.onnx
import netron

def init_weights(m):
    """ initialize weights of fully connected layer,权重和偏置初始化的方式和keras的方式不一样
    """
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0)

# autoencoder with hidden units 20, 2, 20
# Encoder
class Encoder(nn.Module):
    def __init__(self, num_inputs):
        super(Encoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(num_inputs, 256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256,32))
        self.encoder.apply(init_weights)
    def forward(self, x):
        x = self.encoder(x)
        return x
# Decoder
class Decoder(nn.Module):
    def __init__(self, num_inputs):
        super(Decoder, self).__init__()
        self.decoder = nn.Sequential(
            nn.Linear(32, 256),
            nn.ReLU(),
            nn.Linear(256, num_inputs))
        self.decoder.apply(init_weights)#此处init_weights是一个函数
    def forward(self, x):
        x = self.decoder(x)
        return x
# Autoencoder
class autoencoder(nn.Module):
    def __init__(self, num_inputs):
        super(autoencoder, self).__init__()
        self.encoder = Encoder(num_inputs)
        self.decoder = Decoder(num_inputs)
    def forward(self, x):
        code = self.encoder(x)
        x = self.decoder(code)
        return self.encoder.encoder[0].weight,self.decoder.decoder[2].weight,code,x  #注意看这个地方哈，这个地方把中间层得结果直接返回了，就不用自己取了

model=autoencoder(1000)
print(model)
x=torch.rand(1,1000)
m=model(x)
onnx_path = "Retina_model.onnx"
torch.onnx.export(model,x,onnx_path)
netron.start(onnx_path)
#print(model.state_dict())
#print(model.encoder.encoder[0].weight.shape)
#print(model.decoder.decoder[2].weight.shape)
# Out:
# autoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=1000, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=32, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=1000, bias=True)
#     )
#   )
# )
#
# Stopping http://localhost:8080
# Serving 'Retina_model.onnx' at http://localhost:8080

# %% [markdown]
# # training

# %%
print("labda=",labda)
print("num_iter_time=",num_iter)
print("num_batch=",num_batch)
print("sigma_list=",sigma_list)
import numpy as np
import torch
import torch.utils.data #数据加载与预处理
from torch.autograd import Variable
import torch.nn.functional as F #后面有用到F.mseloss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.001,betas=(0.9,0.999))
#optimizer=torch.optim.Adam(model.parameters(),lr=0.001,betas=(0.9,0.999))
logs=np.array([])
mmd=np.array([])
recons=np.array([])


model.train()#会开启batch_normazation的形式

#batch训练集的loss
train_batch_total_loss =np.array([])
train_batch_mmd_loss=np.array([])
train_batch_recons_loss=np.array([])
#epoch训练集的loss
train_epoch_total_loss = []
train_epoch_mmd_loss=[]
train_epoch_recons_loss=[]

#batch 测试集的loss
test_batch_total_loss=np.array([])
test_batch_mmd_loss=np.array([])
test_batch_recons_loss=np.array([])
#epoch 测试集的Loss
test_epoch_total_loss=[]
test_epoch_mmd_loss=[]
test_epoch_recons_loss=[]

for epoch in range(num_iter):
    temp_train_loss = []
    temp_train_mmd_loss=[]
    temp_train_recons_loss=[]
    for input in trainData:
        input=torch.tensor(input)
        input=input.squeeze(0)
        #ipdb.set_trace()
        optimizer.zero_grad() #更新一次
        input=Variable(input)
        w1,w2,encode_data,output=model(input.float())
        split_data=encode_data.chunk(num_batch,dim=0)
        mmd_loss=0;
        for i in split_data:
            for j in split_data:
                mmd_loss+= mix_rbf_mmd2(i,j,sigma_list)
        mmd_loss=mmd_loss*2/(num_batch*(num_batch-1))
        recons_loss=F.mse_loss(input, output)
        regular1=0.01*torch.square(torch.norm(w1))#L2正则化是需要torch.norm()的平方，开始写成了regular1=0.01*torch.norm(w1),发现效果不对
        regular2=0.01*torch.square(torch.norm(w2))
        loss=regular1+regular2+mmd_loss+labda*recons_loss
        loss.backward()
        optimizer.step()
        #print("total_loss=",loss.data.item())
    #print("mmd_loss=",mmd_loss.data.item())
    #print("recons_loss=",recons_loss.data.item())
        temp_train_loss.append(loss.item())        
        temp_train_mmd_loss.append(mmd_loss.item())
        temp_train_recons_loss.append(recons_loss.item())
    
        train_batch_total_loss=np.append(train_batch_total_loss,loss.data.item())
        train_batch_mmd_loss=np.append(train_batch_mmd_loss,mmd_loss.data.item())
        train_batch_recons_loss=np.append(train_batch_recons_loss,recons_loss.data.item())
    print('Epoch{}/{}'.format(epoch,num_iter-1))
    print("TrainSet_epoch_average_total_loss=",np.mean(temp_train_loss))
    print("TrainSet_epoch_average_mmd_loss=",np.mean(temp_train_mmd_loss))
    print("TrainSet_epoch_average_recons_loss=",np.mean(temp_train_recons_loss))
    #ipdb.set_trace()
    train_epoch_total_loss.append(np.mean(temp_train_loss))
    train_epoch_mmd_loss.append(np.mean(temp_train_mmd_loss))
    train_epoch_recons_loss.append(np.mean(temp_train_recons_loss))
    
    
    temp_test_loss = []
    temp_test_mmd_loss=[]
    temp_test_recons_loss=[]

    model.eval()
    for test_input in testData:
        test_input=torch.tensor(test_input)
        test_input=test_input.squeeze(0)
        test_input=Variable(test_input)
        with torch.no_grad():
            w1,w2,encode_data,test_output = model(test_input.float()) 
            split_data=encode_data.chunk(num_batch,dim=0)
            mmd_loss=0;
            for i in split_data:
                for j in split_data:
                    mmd_loss+= mix_rbf_mmd2(i,j,sigma_list)
            mmd_loss=mmd_loss*2/(num_batch*(num_batch-1))
            recons_loss=F.mse_loss(test_input, test_output)    
            total_loss=mmd_loss+labda*recons_loss
            
            temp_test_loss.append(total_loss.item())        
            temp_test_mmd_loss.append(mmd_loss.item())
            temp_test_recons_loss.append(recons_loss.item())
            
            test_batch_total_loss=np.append(test_batch_total_loss,total_loss.data.item())
            test_batch_mmd_loss=np.append(test_batch_mmd_loss,mmd_loss.data.item())
            test_batch_recons_loss=np.append(test_batch_recons_loss,recons_loss.data.item())
            
    test_epoch_total_loss.append(np.mean(temp_test_loss))
    test_epoch_mmd_loss.append(np.mean(temp_test_mmd_loss))
    test_epoch_recons_loss.append(np.mean(temp_test_recons_loss))
print("训练结束")

#ipdb.set_trace()
#训练损失图-batch


x=np.arange(0,num_iter*len(trainData))
plt.figure(figsize=(12,12))

plt.subplot(311)
plt.xlabel("batch")
plt.plot(x,train_batch_total_loss)
plt.title("Training:total_loss:lambda="+str(labda))

plt.subplot(312)
plt.xlabel("batch")
plt.plot(x,train_batch_mmd_loss)
plt.title("Trainging:mmd_loss:lambda="+str(labda))

plt.subplot(313)
plt.xlabel("batch")
plt.plot(x,train_batch_recons_loss)
plt.title("Training:reconstruction_loss:lambda="+str(labda))
plt.show()




#训练损失图-epoch

x=np.arange(0,num_iter)
plt.figure(figsize=(12,12))
plt.subplot(311)
plt.xlabel("epoch")
plt.plot(x,train_epoch_total_loss)
plt.title("[Training]total_loss:lambda="+str(labda))

plt.subplot(312)
plt.xlabel("epoch")
plt.plot(x,train_epoch_mmd_loss)
plt.title("[Training]mmd_loss:lambda="+str(labda))

plt.subplot(313)
plt.xlabel("epoch")
plt.plot(x,train_epoch_recons_loss)
plt.title("[Trainging]reconstruction_loss:lambda="+str(labda))
plt.show()


#画测试集损失图
x=np.arange(0,num_iter*len(testData))
plt.figure(figsize=(12,12))

plt.subplot(311)
plt.xlabel("batch")
plt.plot(x,test_batch_total_loss)
plt.title("Testing:total_loss:lambda="+str(labda))

plt.subplot(312)
plt.xlabel("batch")
plt.plot(x,test_batch_mmd_loss)
plt.title("Testing:mmd_loss:lambda="+str(labda))

plt.subplot(313)
plt.xlabel("batch")
plt.plot(x,test_batch_recons_loss)
plt.title("Testing:reconstruction_loss:lambda="+str(labda))
plt.show()



x=np.arange(0,num_iter)
plt.figure(figsize=(12,12))
plt.subplot(311)
plt.xlabel("epoch")
plt.plot(x,test_epoch_total_loss)
plt.title("[validation]valid_loss:lambda="+str(labda))

plt.subplot(312)
plt.xlabel("epoch")
plt.plot(x,test_epoch_mmd_loss)
plt.title("[validation]mmd_loss:lambda="+str(labda))

plt.subplot(313)
plt.xlabel("epoch")
plt.plot(x,test_epoch_recons_loss)
plt.title("[validation]reconstruction_loss:lambda="+str(labda))
plt.show()
# Out:
# labda= 9
# num_iter_time= 100
# num_batch= 2
# sigma_list= [1.0, 2.0, 4.0]
# Epoch0/99
# TrainSet_epoch_average_total_loss= 11.17695809235038
# TrainSet_epoch_average_mmd_loss= 0.10720002450300066
# TrainSet_epoch_average_recons_loss= 0.9727084595991591
# Epoch1/99
# TrainSet_epoch_average_total_loss= 8.93742632293874
# TrainSet_epoch_average_mmd_loss= 0.10661361726482263
# TrainSet_epoch_average_recons_loss= 0.9535426764570506
# Epoch2/99
# TrainSet_epoch_average_total_loss= 8.70443554595085
# TrainSet_epoch_average_mmd_loss= 0.1138290267312125
# TrainSet_epoch_average_recons_loss= 0.9312933410160614
# Epoch3/99
# TrainSet_epoch_average_total_loss= 8.603467320788544
# TrainSet_epoch_average_mmd_loss= 0.10929442456599033
# TrainSet_epoch_average_recons_loss= 0.921985005691938
# Epoch4/99
# TrainSet_epoch_average_total_loss= 8.644411093786607
# TrainSet_epoch_average_mmd_loss= 0.1111873227558779
# TrainSet_epoch_average_recons_loss= 0.9265967157360037
# Epoch5/99
# TrainSet_epoch_average_total_loss= 8.633253185375246
# TrainSet_epoch_average_mmd_loss= 0.11139897751004509
# TrainSet_epoch_average_recons_loss= 0.924816293451658
# Epoch6/99
# TrainSet_epoch_average_total_loss= 8.5920654792724
# TrainSet_epoch_average_mmd_loss= 0.11222918247908689
# TrainSet_epoch_average_recons_loss= 0.9193009709179916
# Epoch7/99
# TrainSet_epoch_average_total_loss= 8.496259242625808
# TrainSet_epoch_average_mmd_loss= 0.11302342977416649
# TrainSet_epoch_average_recons_loss= 0.9076434590018891
# Epoch8/99
# TrainSet_epoch_average_total_loss= 8.48842921421866
# TrainSet_epoch_average_mmd_loss= 0.11593056495270032
# TrainSet_epoch_average_recons_loss= 0.9053993808539658
# Epoch9/99
# TrainSet_epoch_average_total_loss= 8.460676556315368
# TrainSet_epoch_average_mmd_loss= 0.11542203754521488
# TrainSet_epoch_average_recons_loss= 0.9004081676394812
# Epoch10/99
# TrainSet_epoch_average_total_loss= 8.534674813645612
# TrainSet_epoch_average_mmd_loss= 0.11934484792559334
# TrainSet_epoch_average_recons_loss= 0.905882216319014
# Epoch11/99
# TrainSet_epoch_average_total_loss= 8.335797072849136
# TrainSet_epoch_average_mmd_loss= 0.11949655915913956
# TrainSet_epoch_average_recons_loss= 0.8806074845492345
# Epoch12/99
# TrainSet_epoch_average_total_loss= 8.326378730670022
# TrainSet_epoch_average_mmd_loss= 0.11960878800810053
# TrainSet_epoch_average_recons_loss= 0.8763079877754614
# Epoch13/99
# TrainSet_epoch_average_total_loss= 8.395346920032777
# TrainSet_epoch_average_mmd_loss= 0.12331726577844512
# TrainSet_epoch_average_recons_loss= 0.8799909459173075
# Epoch14/99
# TrainSet_epoch_average_total_loss= 8.278073168003463
# TrainSet_epoch_average_mmd_loss= 0.1212680090344354
# TrainSet_epoch_average_recons_loss= 0.8648660561864635
# Epoch15/99
# TrainSet_epoch_average_total_loss= 8.236566953909685
# TrainSet_epoch_average_mmd_loss= 0.12235283156794109
# TrainSet_epoch_average_recons_loss= 0.8570450805318661
# Epoch16/99
# TrainSet_epoch_average_total_loss= 8.117411722979996
# TrainSet_epoch_average_mmd_loss= 0.12221172828687711
# TrainSet_epoch_average_recons_loss= 0.8420747035991619
# Epoch17/99
# TrainSet_epoch_average_total_loss= 8.111560292473156
# TrainSet_epoch_average_mmd_loss= 0.12326697126198351
# TrainSet_epoch_average_recons_loss= 0.8401137847893123
# Epoch18/99
# TrainSet_epoch_average_total_loss= 8.039559121891873
# TrainSet_epoch_average_mmd_loss= 0.12299619296963295
# TrainSet_epoch_average_recons_loss= 0.8307298901833231
# Epoch19/99
# TrainSet_epoch_average_total_loss= 8.051803428936816
# TrainSet_epoch_average_mmd_loss= 0.12379763685585407
# TrainSet_epoch_average_recons_loss= 0.8302000605655528
# Epoch20/99
# TrainSet_epoch_average_total_loss= 7.977803267261003
# TrainSet_epoch_average_mmd_loss= 0.12390585369273519
# TrainSet_epoch_average_recons_loss= 0.820685878616339
# Epoch21/99
# TrainSet_epoch_average_total_loss= 7.87983640437865
# TrainSet_epoch_average_mmd_loss= 0.12370210919487343
# TrainSet_epoch_average_recons_loss= 0.8096491494043513
# Epoch22/99
# TrainSet_epoch_average_total_loss= 8.019962870334691
# TrainSet_epoch_average_mmd_loss= 0.12348091091667668
# TrainSet_epoch_average_recons_loss= 0.8243840762809177
# Epoch23/99
# TrainSet_epoch_average_total_loss= 7.914812208204799
# TrainSet_epoch_average_mmd_loss= 0.12404108708829023
# TrainSet_epoch_average_recons_loss= 0.8107808216284507
# Epoch24/99
# TrainSet_epoch_average_total_loss= 7.909477683789524
# TrainSet_epoch_average_mmd_loss= 0.12354261846689696
# TrainSet_epoch_average_recons_loss= 0.8100516046613326
# Epoch25/99
# TrainSet_epoch_average_total_loss= 7.806543753869243
# TrainSet_epoch_average_mmd_loss= 0.12325099386860815
# TrainSet_epoch_average_recons_loss= 0.7983444362631932
# Epoch26/99
# TrainSet_epoch_average_total_loss= 7.789149468638252
# TrainSet_epoch_average_mmd_loss= 0.12409412492527051
# TrainSet_epoch_average_recons_loss= 0.7959346733405047
# Epoch27/99
# TrainSet_epoch_average_total_loss= 7.778973175191797
# TrainSet_epoch_average_mmd_loss= 0.12374371390664175
# TrainSet_epoch_average_recons_loss= 0.7945910303361614
# Epoch28/99
# TrainSet_epoch_average_total_loss= 7.771093678695567
# TrainSet_epoch_average_mmd_loss= 0.1235061428520117
# TrainSet_epoch_average_recons_loss= 0.7934289437056334
# Epoch29/99
# TrainSet_epoch_average_total_loss= 7.69618071272843
# TrainSet_epoch_average_mmd_loss= 0.12390269297227431
# TrainSet_epoch_average_recons_loss= 0.7844056268407026
# Epoch30/99
# TrainSet_epoch_average_total_loss= 7.629908865628388
# TrainSet_epoch_average_mmd_loss= 0.12359569757507088
# TrainSet_epoch_average_recons_loss= 0.7770725745987845
# Epoch31/99
# TrainSet_epoch_average_total_loss= 7.649524457842158
# TrainSet_epoch_average_mmd_loss= 0.12334611551480347
# TrainSet_epoch_average_recons_loss= 0.779148168946218
# Epoch32/99
# TrainSet_epoch_average_total_loss= 7.599458929877505
# TrainSet_epoch_average_mmd_loss= 0.12302727695931209
# TrainSet_epoch_average_recons_loss= 0.7734411690358554
# Epoch33/99
# TrainSet_epoch_average_total_loss= 7.676296697817819
# TrainSet_epoch_average_mmd_loss= 0.12294229689273942
# TrainSet_epoch_average_recons_loss= 0.7809560183851078
# Epoch34/99
# TrainSet_epoch_average_total_loss= 7.552559541285178
# TrainSet_epoch_average_mmd_loss= 0.12324904081191909
# TrainSet_epoch_average_recons_loss= 0.7673835752276155
# Epoch35/99
# TrainSet_epoch_average_total_loss= 7.632405287260914
# TrainSet_epoch_average_mmd_loss= 0.12298648955112093
# TrainSet_epoch_average_recons_loss= 0.774998856264162
# Epoch36/99
# TrainSet_epoch_average_total_loss= 7.560864174154395
# TrainSet_epoch_average_mmd_loss= 0.12285473097241327
# TrainSet_epoch_average_recons_loss= 0.7674150231241765
# Epoch37/99
# TrainSet_epoch_average_total_loss= 7.558818602620208
# TrainSet_epoch_average_mmd_loss= 0.12247155698832501
# TrainSet_epoch_average_recons_loss= 0.7669393373850572
# Epoch38/99
# TrainSet_epoch_average_total_loss= 7.5267457708433705
# TrainSet_epoch_average_mmd_loss= 0.1226091647750876
# TrainSet_epoch_average_recons_loss= 0.7630979232821415
# Epoch39/99
# TrainSet_epoch_average_total_loss= 7.40058287139914
# TrainSet_epoch_average_mmd_loss= 0.12253155190958066
# TrainSet_epoch_average_recons_loss= 0.7499081639748955
# Epoch40/99
# TrainSet_epoch_average_total_loss= 7.402703287813121
# TrainSet_epoch_average_mmd_loss= 0.12254429215125823
# TrainSet_epoch_average_recons_loss= 0.7500883322140125
# Epoch41/99
# TrainSet_epoch_average_total_loss= 7.402238827167946
# TrainSet_epoch_average_mmd_loss= 0.12227225261792708
# TrainSet_epoch_average_recons_loss= 0.7501143996294006
# Epoch42/99
# TrainSet_epoch_average_total_loss= 7.409981282265634
# TrainSet_epoch_average_mmd_loss= 0.1223359066113997
# TrainSet_epoch_average_recons_loss= 0.7507635738994706
# Epoch43/99
# TrainSet_epoch_average_total_loss= 7.37725803800735
# TrainSet_epoch_average_mmd_loss= 0.12226548405845514
# TrainSet_epoch_average_recons_loss= 0.7471995971052026
# Epoch44/99
# TrainSet_epoch_average_total_loss= 7.349024143472084
# TrainSet_epoch_average_mmd_loss= 0.12235090638814347
# TrainSet_epoch_average_recons_loss= 0.7441063896500891
# Epoch45/99
# TrainSet_epoch_average_total_loss= 7.423646716627626
# TrainSet_epoch_average_mmd_loss= 0.12221051903253191
# TrainSet_epoch_average_recons_loss= 0.7518323650265732
# Epoch46/99
# TrainSet_epoch_average_total_loss= 7.308396641384289
# TrainSet_epoch_average_mmd_loss= 0.12205625660298916
# TrainSet_epoch_average_recons_loss= 0.7395582348584465
# Epoch47/99
# TrainSet_epoch_average_total_loss= 7.3467048227996194
# TrainSet_epoch_average_mmd_loss= 0.12205043552296885
# TrainSet_epoch_average_recons_loss= 0.7440681378144326
# Epoch48/99
# TrainSet_epoch_average_total_loss= 7.351862213847889
# TrainSet_epoch_average_mmd_loss= 0.12172937116930994
# TrainSet_epoch_average_recons_loss= 0.7448538086679853
# Epoch49/99
# TrainSet_epoch_average_total_loss= 7.4025356109326585
# TrainSet_epoch_average_mmd_loss= 0.12196550861503301
# TrainSet_epoch_average_recons_loss= 0.7491224395064612
# Epoch50/99
# TrainSet_epoch_average_total_loss= 7.353984394165356
# TrainSet_epoch_average_mmd_loss= 0.12191983052853787
# TrainSet_epoch_average_recons_loss= 0.7438065071154456
# Epoch51/99
# TrainSet_epoch_average_total_loss= 7.318594922038149
# TrainSet_epoch_average_mmd_loss= 0.1217780155914553
# TrainSet_epoch_average_recons_loss= 0.7412727764851452
# Epoch52/99
# TrainSet_epoch_average_total_loss= 7.239131730844983
# TrainSet_epoch_average_mmd_loss= 0.12169621884822845
# TrainSet_epoch_average_recons_loss= 0.7334745249032955
# Epoch53/99
# TrainSet_epoch_average_total_loss= 7.258587167168128
# TrainSet_epoch_average_mmd_loss= 0.12213200330734253
# TrainSet_epoch_average_recons_loss= 0.7354201267794199
# Epoch54/99
# TrainSet_epoch_average_total_loss= 7.1749229958164324
# TrainSet_epoch_average_mmd_loss= 0.12169458164592807
# TrainSet_epoch_average_recons_loss= 0.7266072048745029
# Epoch55/99
# TrainSet_epoch_average_total_loss= 7.216860077447128
# TrainSet_epoch_average_mmd_loss= 0.12178814126534408
# TrainSet_epoch_average_recons_loss= 0.7311548651037547
# Epoch56/99
# TrainSet_epoch_average_total_loss= 7.208988197626519
# TrainSet_epoch_average_mmd_loss= 0.12182159663251277
# TrainSet_epoch_average_recons_loss= 0.730599812788593
# Epoch57/99
# TrainSet_epoch_average_total_loss= 7.240895716664267
# TrainSet_epoch_average_mmd_loss= 0.12177804874235325
# TrainSet_epoch_average_recons_loss= 0.7333747841299589
# Epoch58/99
# TrainSet_epoch_average_total_loss= 7.202187830421173
# TrainSet_epoch_average_mmd_loss= 0.12188456274485321
# TrainSet_epoch_average_recons_loss= 0.7294312351217072
# Epoch59/99
# TrainSet_epoch_average_total_loss= 7.18696152725871
# TrainSet_epoch_average_mmd_loss= 0.12185305373722248
# TrainSet_epoch_average_recons_loss= 0.7284189448865109
# Epoch60/99
# TrainSet_epoch_average_total_loss= 7.207534236406259
# TrainSet_epoch_average_mmd_loss= 0.12177006699395983
# TrainSet_epoch_average_recons_loss= 0.7305392435673678
# Epoch61/99
# TrainSet_epoch_average_total_loss= 7.149532656233536
# TrainSet_epoch_average_mmd_loss= 0.12160829019345594
# TrainSet_epoch_average_recons_loss= 0.7247620832807605
# Epoch62/99
# TrainSet_epoch_average_total_loss= 7.104122345485104
# TrainSet_epoch_average_mmd_loss= 0.12181562545259347
# TrainSet_epoch_average_recons_loss= 0.7201836053482815
# Epoch63/99
# TrainSet_epoch_average_total_loss= 7.147710059130905
# TrainSet_epoch_average_mmd_loss= 0.12134467550877774
# TrainSet_epoch_average_recons_loss= 0.7253482677739854
# Epoch64/99
# TrainSet_epoch_average_total_loss= 7.118686503866523
# TrainSet_epoch_average_mmd_loss= 0.12161678494362349
# TrainSet_epoch_average_recons_loss= 0.7225449657423189
# Epoch65/99
# TrainSet_epoch_average_total_loss= 7.10475579372839
# TrainSet_epoch_average_mmd_loss= 0.12169255333000355
# TrainSet_epoch_average_recons_loss= 0.721235217114833
# Epoch66/99
# TrainSet_epoch_average_total_loss= 7.098738307974676
# TrainSet_epoch_average_mmd_loss= 0.12177694254042057
# TrainSet_epoch_average_recons_loss= 0.7200718524239144
# Epoch67/99
# TrainSet_epoch_average_total_loss= 7.129463318732607
# TrainSet_epoch_average_mmd_loss= 0.12168661237097858
# TrainSet_epoch_average_recons_loss= 0.7244128086711573
# Epoch68/99
# TrainSet_epoch_average_total_loss= 7.07953300445721
# TrainSet_epoch_average_mmd_loss= 0.12141493917181251
# TrainSet_epoch_average_recons_loss= 0.7188346415086017
# Epoch69/99
# TrainSet_epoch_average_total_loss= 7.0656406013130555
# TrainSet_epoch_average_mmd_loss= 0.1214543909169315
# TrainSet_epoch_average_recons_loss= 0.7172670001727152
# Epoch70/99
# TrainSet_epoch_average_total_loss= 7.12147584122157
# TrainSet_epoch_average_mmd_loss= 0.12157240660672777
# TrainSet_epoch_average_recons_loss= 0.7231273672702073
# Epoch71/99
# TrainSet_epoch_average_total_loss= 7.07890349764505
# TrainSet_epoch_average_mmd_loss= 0.1216651951329092
# TrainSet_epoch_average_recons_loss= 0.7191764762234923
# Epoch72/99
# TrainSet_epoch_average_total_loss= 7.079976705239226
# TrainSet_epoch_average_mmd_loss= 0.12154458555277814
# TrainSet_epoch_average_recons_loss= 0.7192752340335707
# Epoch73/99
# TrainSet_epoch_average_total_loss= 7.053386595706675
# TrainSet_epoch_average_mmd_loss= 0.12158424658386895
# TrainSet_epoch_average_recons_loss= 0.717108345347481
# Epoch74/99
# TrainSet_epoch_average_total_loss= 7.0572743669861
# TrainSet_epoch_average_mmd_loss= 0.1217971427387066
# TrainSet_epoch_average_recons_loss= 0.7171354982834204
# Epoch75/99
# TrainSet_epoch_average_total_loss= 7.07738765354552
# TrainSet_epoch_average_mmd_loss= 0.12175017863177182
# TrainSet_epoch_average_recons_loss= 0.7197177273023669
# Epoch76/99
# TrainSet_epoch_average_total_loss= 7.069481501166782
# TrainSet_epoch_average_mmd_loss= 0.12170767290203759
# TrainSet_epoch_average_recons_loss= 0.7193913103060823
# Epoch77/99
# TrainSet_epoch_average_total_loss= 7.032714466781689
# TrainSet_epoch_average_mmd_loss= 0.12152202301815654
# TrainSet_epoch_average_recons_loss= 0.7156841135889248
# Epoch78/99
# TrainSet_epoch_average_total_loss= 7.061344790865391
# TrainSet_epoch_average_mmd_loss= 0.12156714323196519
# TrainSet_epoch_average_recons_loss= 0.7184082232318783
# Epoch79/99
# TrainSet_epoch_average_total_loss= 7.053125384265612
# TrainSet_epoch_average_mmd_loss= 0.1217998828780785
# TrainSet_epoch_average_recons_loss= 0.7175173000580019
# Epoch80/99
# TrainSet_epoch_average_total_loss= 6.980327593415209
# TrainSet_epoch_average_mmd_loss= 0.12147084213374706
# TrainSet_epoch_average_recons_loss= 0.7103554511121117
# Epoch81/99
# TrainSet_epoch_average_total_loss= 6.990942950625417
# TrainSet_epoch_average_mmd_loss= 0.12163704089569242
# TrainSet_epoch_average_recons_loss= 0.7118923662189893
# Epoch82/99
# TrainSet_epoch_average_total_loss= 7.029320562681531
# TrainSet_epoch_average_mmd_loss= 0.12147552394465114
# TrainSet_epoch_average_recons_loss= 0.716119379049838
# Epoch83/99
# TrainSet_epoch_average_total_loss= 7.026180485686382
# TrainSet_epoch_average_mmd_loss= 0.12152451008893131
# TrainSet_epoch_average_recons_loss= 0.7155005353694951
# Epoch84/99
# TrainSet_epoch_average_total_loss= 7.013371466682048
# TrainSet_epoch_average_mmd_loss= 0.12130799780735808
# TrainSet_epoch_average_recons_loss= 0.7140781278648758
# Epoch85/99
# TrainSet_epoch_average_total_loss= 7.019958427012919
# TrainSet_epoch_average_mmd_loss= 0.12146448863021443
# TrainSet_epoch_average_recons_loss= 0.7151838577381845
# Epoch86/99
# TrainSet_epoch_average_total_loss= 7.075919449943213
# TrainSet_epoch_average_mmd_loss= 0.12158972108631991
# TrainSet_epoch_average_recons_loss= 0.720394044103736
# Epoch87/99
# TrainSet_epoch_average_total_loss= 7.053345525075148
# TrainSet_epoch_average_mmd_loss= 0.12152860615025746
# TrainSet_epoch_average_recons_loss= 0.7183723905349123
# Epoch88/99
# TrainSet_epoch_average_total_loss= 6.9833004129249865
# TrainSet_epoch_average_mmd_loss= 0.12183958149692986
# TrainSet_epoch_average_recons_loss= 0.7119396692378482
# Epoch89/99
# TrainSet_epoch_average_total_loss= 7.025612253584438
# TrainSet_epoch_average_mmd_loss= 0.12175989209601049
# TrainSet_epoch_average_recons_loss= 0.7165432227570413
# Epoch90/99
# TrainSet_epoch_average_total_loss= 6.993636583110494
# TrainSet_epoch_average_mmd_loss= 0.12194744254765885
# TrainSet_epoch_average_recons_loss= 0.7134657900022995
# Epoch91/99
# TrainSet_epoch_average_total_loss= 7.011326775588254
# TrainSet_epoch_average_mmd_loss= 0.12143882204977315
# TrainSet_epoch_average_recons_loss= 0.7148231973136009
# Epoch92/99
# TrainSet_epoch_average_total_loss= 7.019753448231535
# TrainSet_epoch_average_mmd_loss= 0.1213690722256564
# TrainSet_epoch_average_recons_loss= 0.7160466611926737
# Epoch93/99
# TrainSet_epoch_average_total_loss= 7.065011504634235
# TrainSet_epoch_average_mmd_loss= 0.12157272555854882
# TrainSet_epoch_average_recons_loss= 0.7205880189775591
# Epoch94/99
# TrainSet_epoch_average_total_loss= 6.949887784739694
# TrainSet_epoch_average_mmd_loss= 0.12149054188741727
# TrainSet_epoch_average_recons_loss= 0.7085188682375629
# Epoch95/99
# TrainSet_epoch_average_total_loss= 6.955883367290593
# TrainSet_epoch_average_mmd_loss= 0.12166151178351949
# TrainSet_epoch_average_recons_loss= 0.7103777072716819
# Epoch96/99
# TrainSet_epoch_average_total_loss= 6.94671700148164
# TrainSet_epoch_average_mmd_loss= 0.12173490176040135
# TrainSet_epoch_average_recons_loss= 0.7094415494417096
# Epoch97/99
# TrainSet_epoch_average_total_loss= 6.993867588070942
# TrainSet_epoch_average_mmd_loss= 0.12146148412080293
# TrainSet_epoch_average_recons_loss= 0.7145431149498059
# Epoch98/99
# TrainSet_epoch_average_total_loss= 7.003533176617966
# TrainSet_epoch_average_mmd_loss= 0.12139886450231745
# TrainSet_epoch_average_recons_loss= 0.71515149980809
# Epoch99/99
# TrainSet_epoch_average_total_loss= 7.008113690916257
# TrainSet_epoch_average_mmd_loss= 0.12143030092957315
# TrainSet_epoch_average_recons_loss= 0.7161381604750563
# 训练结束

# %% [markdown]
# # 中间层可视化

# %%
model.eval()
#中间层UMAP可视化
_,_,encode_data,_=model(torch.tensor(adata_con.X))
encode_data=sc.AnnData(encode_data.data.numpy(),obs=adata_con.obs) 
sc.pp.neighbors(encode_data,n_neighbors=15,random_state=0)
sc.tl.umap(encode_data)
sc.pl.umap(encode_data,color=['BatchIDnew','BatchID','celltype'])
# print(type(encode_data))
# print(encode_data.size())
# print(encode_data.data.numpy())

# %%
def find_resolution(adata_, n_clusters, random): 
    adata = adata_.copy()
    obtained_clusters = -1
    iteration = 0
    resolutions = [0., 1000.]
    while obtained_clusters != n_clusters and iteration < 50:
        current_res = sum(resolutions)/2
        sc.tl.louvain(adata, resolution = current_res, random_state = random)
        labels = adata.obs['louvain']
        obtained_clusters = len(np.unique(labels))
        
        if obtained_clusters < n_clusters:
            resolutions[0] = current_res
        else:
            resolutions[1] = current_res
        iteration = iteration + 1
    return current_res
reso=find_resolution(encode_data,14,0)
sc.tl.louvain(encode_data,resolution=reso,random_state=0)
from sklearn.metrics.cluster import adjusted_rand_score,normalized_mutual_info_score
ARI= adjusted_rand_score(encode_data.obs["celltype"], encode_data.obs["louvain"])
NMI= normalized_mutual_info_score(encode_data.obs["celltype"], encode_data.obs["louvain"])
sc.pl.umap(encode_data,color=["louvain","celltype"],title=["louvain:"+"ARI:"+str(round(ARI,3))+",NMI:"+str(round(NMI,3)),"celltype"])

# %%
print(adata_train["bt1"].shape)
print(adata_train["bt2"].shape)
print(adata_test["bt1"].shape)
print(adata_test["bt2"].shape)
# Out:
# (9891, 1000)
# (8904, 1000)
# (2473, 1000)
# (2226, 1000)
